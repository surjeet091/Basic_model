# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import json
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
ds = pd.read_csv("Data source//backup.csv")
da=ds.drop(columns=['clas',"veg /Non- Veg","Unnamed: 0"])

# %%
v=da['Total No of Ratings']
R=da['Rating']
C=da['Rating'].mean()
m=da['Total No of Ratings'].quantile(0.70)

# %%
da['weighted_average']=((R*v)+ (C*m))/(v+m)

# %%
res_ranking=da.sort_values('weighted_average',ascending=False)
#weight_average=res_ranking.sort_values('weighted_average',ascending=False)

# %%
res_ranking.head()
# Out:
#             Name of Restaurent         Type of Cusine  Rating  \
# 357                Stanley Park                  Park     4.8
# 2                Miku Vancouver                 Sushi     4.6
# 281  Hotel Fairmont Pacific Rim            Restaurant     4.6
# 349                   Purebread  Bakery and Cake Shop     4.7
# 42                  Ramen DANBO                 Ramen     4.6
#
#      Total No of Ratings  Classify          Cost   Dine_in_availability  \
# 357                31717         1  Average Cost  DIne In Not Available
# 2                   4201         1     Expensive  DIne In Not Available
# 281                 3592         1  Average Cost  DIne In Not Available
# 349                 1323         1  Average Cost  DIne In Not Available
# 42                  2311         1  Average Cost                Dine-in
#
#               Takeaway_type   Delivery_availability   Flexiability  Dine  \
# 357  Take  In Not Available  Dilivery Not Available  Not Flexiable     0
# 2    Take  In Not Available  Dilivery Not Available  Not Flexiable     0
# 281  Take  In Not Available  Dilivery Not Available  Not Flexiable     0
# 349  Take  In Not Available  Dilivery Not Available  Not Flexiable     0
# 42                 Takeaway                Delivery      Flexiable     1
#
#      Take  deli  Flex Opening_time  \
# 357     0     0     0          9AM
# 2       0     0     0      11:30AM
# 281     0     0     0         10AM
# 349     0     0     0       8:30AM
# 42      1     1     1         11AM
#
#                          Description of the Restaurent  \
# 357  Vancouver's largest urban park boasts beaches,...
# 2    Sushi & sustainable seafood are served in a so...
# 281  Luxe lodging in a striking building offering 3...
# 349                                     No Description
# 42                                      No Description
#
#                                 Location and Address               Landmark  \
# 357                                        Canvouver  Vancouver, BC, Canada
# 2    200 Granville St # 70 ú In the Granville Square  Vancouver, BC, Canada
# 281                                        Canvouver         1038 Canada Pl
# 349                            Vancouver, BC, Canada  Vancouver, BC, Canada
# 42                                         Canvouver  Vancouver, BC, Canada
#
#     Current Status  weighted_average
# 357         Closed          4.782107
# 2           Closed          4.529963
# 281         Closed          4.520841
# 349         Closed          4.501183
# 42          Closed          4.490971
